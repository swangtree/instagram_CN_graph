# %% [markdown]
# ## Import libraries

# %%
import networkx as nx
import pandas as pd
import os
import glob
import matplotlib
import scipy
import time
from collections import Counter

# %% [markdown]
# ## Build Network from CSVs

# %%
username_dict = {
    "samuel": "swang330",
    "alex": "alex.kalis",
    "alexandra": "alexandrapurdy_",
    "kabir": "kabir_aho",
    "kirin": "kirindanek",
    "liam": "liam_hochman",
    "noah": "noahpurow",
    "seoeun": "seoeunki.m",
    "will": "will.deley",
    "zach": "zach.annuik",
    "yota": "yota.katsikouli",
    "dis_abroad": "dis.copenhagen",
    "ely": "elybrayboy"
}

# %%
current_dir = os.path.dirname(os.getcwd())
csv_directory = os.path.join(current_dir, "final_project", "csv_files")

def build_network_from_csvs(csv_dir, exclude_user=None):
    G = nx.DiGraph()
    csv_files = glob.glob(os.path.join(csv_dir, "*_data.csv"))

    if not csv_files:
        print(f"error: no '*_data.csv' files found in directory: {csv_dir}")
        return None

    print(f"found {len(csv_files)} CSV files to process.")

    for csv_path in csv_files:
        filename = os.path.basename(csv_path)
        print(f"processing: {filename}...")

        parts = filename.replace("_data.csv", "").split('_')
        if len(parts) < 2:
            print(f"warning: skipping file with unexpected name format: {filename}")
            continue

        file_prefix = "_".join(parts[:-1])
        central_node = username_dict.get(file_prefix)

        #skip if excluding this user or if mapping failed
        if central_node == exclude_user or central_node is None:
            if central_node == exclude_user:
                 print(f"-> skipping file for excluded central node: {central_node}")
            else:
                print("warning: Skipping file - could not map prefix {} to a username: {}".format(file_prefix, filename))
            continue

        print(central_node) # Print the central node only if not skipped

        relationship_type = parts[-1]
        if relationship_type not in ["followers", "following"]:
            print(f"warning: Skipping file - cannot determine relationship type: {filename}")
            continue

        G.add_node(central_node)

        try:
            df = pd.read_csv(csv_path)
            if "username" not in df.columns:
                print(f"warning: Skipping file - 'username' column not found in {filename}")
                continue

            other_users = df["username"].dropna().unique()

            count = 0
            for user in other_users:
                #skip edges involving the excluded user
                if user == exclude_user:
                    continue

                G.add_node(user)

                if relationship_type == "followers":
                    G.add_edge(user, central_node)
                    count += 1
                elif relationship_type == "following":
                    G.add_edge(central_node, user)
                    count += 1

            print(f"-> added {count} edges for {central_node} ({relationship_type}).") # adjusted count

        except pd.errors.EmptyDataError:
             print(f"warning: Skipping empty file: {filename}")
        except Exception as e:
            print(f"error processing file {filename}: {e}")

    return G

# %%
network_graph = build_network_from_csvs(csv_directory)
# Out:
# found 26 CSV files to process.
# processing: dis_abroad_followers_data.csv...
# dis.copenhagen
# -> added 4856 edges for dis.copenhagen (followers).
# processing: samuel_following_data.csv...
# swang330
# -> added 1104 edges for swang330 (following).
# processing: alex_following_data.csv...
# alex.kalis
# -> added 1675 edges for alex.kalis (following).
# processing: zach_followers_data.csv...
# zach.annuik
# -> added 603 edges for zach.annuik (followers).
# processing: liam_followers_data.csv...
# liam_hochman
# -> added 817 edges for liam_hochman (followers).
# processing: dis_abroad_following_data.csv...
# dis.copenhagen
# -> added 240 edges for dis.copenhagen (following).
# processing: samuel_followers_data.csv...
# swang330
# -> added 683 edges for swang330 (followers).
# processing: liam_following_data.csv...
# liam_hochman
# -> added 1678 edges for liam_hochman (following).
# processing: alex_followers_data.csv...
# alex.kalis
# -> added 1235 edges for alex.kalis (followers).
# processing: zach_following_data.csv...
# zach.annuik
# -> added 1066 edges for zach.annuik (following).
# processing: kirin_following_data.csv...
# kirindanek
# -> added 1533 edges for kirindanek (following).
# processing: yota_following_data.csv...
# yota.katsikouli
# -> added 185 edges for yota.katsikouli (following).
# processing: kabir_following_data.csv...
# kabir_aho
# -> added 2346 edges for kabir_aho (following).
# processing: kirin_followers_data.csv...
# kirindanek
# -> added 824 edges for kirindanek (followers).
# processing: yota_followers_data.csv...
# yota.katsikouli
# -> added 147 edges for yota.katsikouli (followers).
# processing: kabir_followers_data.csv...
# kabir_aho
# -> added 827 edges for kabir_aho (followers).
# processing: ely_following_data.csv...
# elybrayboy
# -> added 1471 edges for elybrayboy (following).
# processing: noah_followers_data.csv...
# noahpurow
# -> added 789 edges for noahpurow (followers).
# processing: will_following_data.csv...
# will.deley
# -> added 704 edges for will.deley (following).
# processing: seoeun_followers_data.csv...
# seoeunki.m
# -> added 1136 edges for seoeunki.m (followers).
# processing: ely_followers_data.csv...
# elybrayboy
# -> added 892 edges for elybrayboy (followers).
# processing: noah_following_data.csv...
# noahpurow
# -> added 1603 edges for noahpurow (following).
# processing: seoeun_following_data.csv...
# seoeunki.m
# -> added 1403 edges for seoeunki.m (following).
# processing: will_followers_data.csv...
# will.deley
# -> added 631 edges for will.deley (followers).
# processing: alexandra_following_data.csv...
# alexandrapurdy_
# -> added 869 edges for alexandrapurdy_ (following).
# processing: alexandra_followers_data.csv...
# alexandrapurdy_
# -> added 711 edges for alexandrapurdy_ (followers).

# %% [markdown]
# ### Degrees of class members

# %%
for username in username_dict.values():
    if network_graph.has_node(username):
        in_deg = network_graph.in_degree(username)
        out_deg = network_graph.out_degree(username)
        print(f"- {username}: In={in_deg}, Out={out_deg}")
    else:
        print(f"error: {username} not found in the full graph")
# Out:
# - swang330: In=685, Out=1105
# - alex.kalis: In=1235, Out=1675
# - alexandrapurdy_: In=711, Out=869
# - kabir_aho: In=828, Out=2346
# - kirindanek: In=825, Out=1535
# - liam_hochman: In=817, Out=1678
# - noahpurow: In=789, Out=1603
# - seoeunki.m: In=1136, Out=1403
# - will.deley: In=631, Out=704
# - zach.annuik: In=604, Out=1076
# - yota.katsikouli: In=147, Out=185
# - dis.copenhagen: In=4857, Out=240
# - elybrayboy: In=892, Out=1471

# %% [markdown]
# ### Largest SCC

# %%
sccs = list(nx.strongly_connected_components(network_graph))
scc_sizes = [len(component) for component in sccs]

print(f"Found {len(scc_sizes)} strongly connected components.")

if scc_sizes:
    max_scc_size = max(scc_sizes)
    print(f"Size of the largest strongly connected component: {max_scc_size}")

    nodes_in_cycles = sum(size for size in scc_sizes if size > 1)
    print(f"Total number of nodes in non-trivial SCCs (size > 1): {nodes_in_cycles}")

    #find the largest SCC
    largest_scc_nodes = max(sccs, key=len)
    lscc_graph = network_graph.subgraph(largest_scc_nodes)
    print(f"LSCC Graph: Nodes={lscc_graph.number_of_nodes()}, Edges={lscc_graph.number_of_edges()}")
# Out:
# Found 14674 strongly connected components.
# Size of the largest strongly connected component: 7278
# Total number of nodes participating in non-trivial SCCs (size > 1): 7278
# LSCC Graph: Nodes=7278, Edges=15067

# %%
class_members = list(username_dict.values())
individual_reciprocity = nx.reciprocity(network_graph, nodes=class_members)
for node, recip in individual_reciprocity.items():
        if network_graph.has_node(node) and network_graph.degree(node) > 0:
            print(f"- {node}: {recip:.4f}")
        else:
            print(f"- {node}: Error")
# Out:
# - swang330: 0.7385
# - alex.kalis: 0.6460
# - alexandrapurdy_: 0.7316
# - kabir_aho: 0.4171
# - kirindanek: 0.6415
# - liam_hochman: 0.5796
# - noahpurow: 0.5418
# - seoeunki.m: 0.6010
# - will.deley: 0.6172
# - zach.annuik: 0.5571
# - yota.katsikouli: 0.6084
# - dis.copenhagen: 0.0094
# - elybrayboy: 0.5942

# %% [markdown]
# ### Diameter of directed graph

# %%
diameter_lscc = nx.diameter(lscc_graph)
print(f"Diameter of largest SCC (directed): {diameter_lscc}")
# Out:
# Diameter of largest SCC (directed): 6

# %% [markdown]
# Find actual path of diameter 6

# %%
eccentricities = nx.eccentricity(lscc_graph) #list max directions
source_node = None
for node, ecc in eccentricities.items():
    if ecc == diameter_lscc:
        source_node = node
        print(f"Found source node '{source_node}' with eccentricity {ecc}")
        break

# check if diameter matches path between nodes
if source_node:
    print(f"Calculating shortest paths from '{source_node}'...")
    path_lengths_from_source = nx.shortest_path_length(lscc_graph, source=source_node)
    target_node = None
    for node, length in path_lengths_from_source.items():
        if length == diameter_lscc:
            target_node = node
            print(f"Found target node '{target_node}' at distance {diameter_lscc}")
            break

    if target_node:
        actual_path = nx.shortest_path(lscc_graph, source=source_node, target=target_node)

        print(f"Length: {len(actual_path) - 1} (Matches diameter: {len(actual_path) - 1 == diameter_lscc})")
        print(f"Source: {source_node}")
        print(f"Target: {target_node}")
        print(f"Path: {actual_path}")
# Out:
# Found source node '__annamacdonald__' with eccentricity 6
# Calculating shortest paths from '__annamacdonald__'...
# Found target node 'miltiades_official' at distance 6
# Length: 6 (Matches diameter: True)
# Source: __annamacdonald__
# Target: miltiades_official
# Path: ['__annamacdonald__', 'dis.copenhagen', 'sally.bornhorst', 'zach.annuik', 'swang330', 'yota.katsikouli', 'miltiades_official']

# %% [markdown]
# In order for a node to be in a cycle of length 3 given the structure of our network and how it's built (outward from the core class members), in order for a node to be in a cycle of length 3 (asymetric or not) it must be in the largest SCC, therefore we're only to look at nodes in the LSCC to save on a lot of computation.

# %% [markdown]
# ## Asymetric cycles of Length 3

# %%
asymmetric_cycles_len3 = []
print("\n--- Asymmetric 3-Cycle Search (Full LSCC) ---")
target_graph = lscc_graph
print(f"Starting search in 'lscc_graph' (Nodes: {target_graph.number_of_nodes()}, Edges: {target_graph.number_of_edges()})...")
start_time = time.time()

found_unique_cycles_set = set()
nodes_processed = 0
total_nodes = target_graph.number_of_nodes()

for u in target_graph:
    nodes_processed += 1
    for v in target_graph[u]:
        for w in target_graph[v]:
            #check for cycle of 3 and asymetry
            if w != u and target_graph.has_edge(w, u):
                is_symmetric = (target_graph.has_edge(v, u) and
                                target_graph.has_edge(w, v) and
                                target_graph.has_edge(u, w))
                if not is_symmetric:
                    cycle = [u, v, w]
                    #create unique identifier (sorted tuple of nodes)
                    sorted_cycle_tuple = tuple(sorted(cycle))
                    if sorted_cycle_tuple not in found_unique_cycles_set:
                        found_unique_cycles_set.add(sorted_cycle_tuple)
                        asymmetric_cycles_len3.append(cycle)

    if nodes_processed % 1000 == 0:
            print(f"  ... processed {nodes_processed}/{total_nodes} nodes...")

end_time = time.time()
found_count = len(asymmetric_cycles_len3)
print(f"\nSearch Complete. Found {found_count} unique asymmetric cycles of length 3.")
print(f"Time taken: {end_time - start_time:.2f} seconds.")

if asymmetric_cycles_len3:
    print(f"\nPrinting asymmetric length 3 cycles found:")
    for i, cycle in enumerate(asymmetric_cycles_len3):
        print(f"- Cycle {i+1}: {cycle}")
# Out:
# --- Asymmetric 3-Cycle Search (Full LSCC) ---
# Starting search in 'lscc_graph' (Nodes: 7278, Edges: 15067)...
#   ... processed 1000/7278 nodes...
#   ... processed 2000/7278 nodes...
#   ... processed 3000/7278 nodes...
#   ... processed 4000/7278 nodes...
#   ... processed 5000/7278 nodes...
#   ... processed 6000/7278 nodes...
#   ... processed 7000/7278 nodes...
#
# Search Complete. Found 120 unique asymmetric cycles of length 3.
# Time taken: 4.00 seconds.
#
# Printing asymmetric length 3 cycles found:
# - Cycle 1: ['anderss.k', 'zach.annuik', 'kirindanek']
# - Cycle 2: ['anderss.k', 'zach.annuik', 'kabir_aho']
# - Cycle 3: ['feyza_achilova', 'elybrayboy', 'noahpurow']
# - Cycle 4: ['madigoeke', 'elybrayboy', 'noahpurow']
# - Cycle 5: ['harshxk_', 'will.deley', 'alex.kalis']
# - Cycle 6: ['cayeetanaaa', 'noahpurow', 'elybrayboy']
# - Cycle 7: ['brownumemes', 'elybrayboy', 'noahpurow']
# - Cycle 8: ['jake_levy61', 'will.deley', 'alex.kalis']
# - Cycle 9: ['_annikasingh', 'noahpurow', 'elybrayboy']
# - Cycle 10: ['libbydakers', 'elybrayboy', 'noahpurow']
# - Cycle 11: ['myopiamilos', 'swang330', 'liam_hochman']
# - Cycle 12: ['katy_wales17', 'alex.kalis', 'will.deley']
# - Cycle 13: ['baybater', 'swang330', 'liam_hochman']
# - Cycle 14: ['baybater', 'swang330', 'alex.kalis']
# - Cycle 15: ['arsh_chow', 'seoeunki.m', 'kabir_aho']
# - Cycle 16: ['_harrison.brown_', 'liam_hochman', 'swang330']
# - Cycle 17: ['katrinatruong', 'elybrayboy', 'noahpurow']
# - Cycle 18: ['edgr_oh', 'zach.annuik', 'alexandrapurdy_']
# - Cycle 19: ['a.fitenko', 'seoeunki.m', 'liam_hochman']
# - Cycle 20: ['catherinejia_', 'elybrayboy', 'noahpurow']
# - Cycle 21: ['_kate.choi', 'noahpurow', 'elybrayboy']
# - Cycle 22: ['lucyc1ark', 'zach.annuik', 'elybrayboy']
# - Cycle 23: ['marazwicker_', 'will.deley', 'alex.kalis']
# - Cycle 24: ['liam_hochman', 'swang330', 'rezspuffs']
# - Cycle 25: ['liam_hochman', 'swang330', 'joshu.ms']
# - Cycle 26: ['liam_hochman', 'swang330', 'jake_cole08']
# - Cycle 27: ['liam_hochman', 'swang330', 'jacobzarate13']
# - Cycle 28: ['liam_hochman', 'swang330', 'brianngiraud']
# - Cycle 29: ['liam_hochman', 'swang330', 'j.dstag']
# - Cycle 30: ['liam_hochman', 'swang330', 'tslnew']
# - Cycle 31: ['liam_hochman', 'swang330', 'bennetdude']
# - Cycle 32: ['liam_hochman', 'emilycharestt', 'swang330']
# - Cycle 33: ['liam_hochman', 'kellxj', 'swang330']
# - Cycle 34: ['liam_hochman', 'kirindanek', 'lillieofthesky']
# - Cycle 35: ['liam_hochman', 'taramukund', 'swang330']
# - Cycle 36: ['liam_hochman', 'jjessica.zhang', 'swang330']
# - Cycle 37: ['liam_hochman', 'scrippsadvocates', 'swang330']
# - Cycle 38: ['liam_hochman', 'seoeunki.m', '_anders_hansen']
# - Cycle 39: ['liam_hochman', 'alexandrapurdy_', 'solanaoshea']
# - Cycle 40: ['liam_hochman', 'alexandrapurdy_', 'soph.zwu']
# - Cycle 41: ['liam_hochman', 'alexandrapurdy_', 'nadia.schwartz']
# - Cycle 42: ['liam_hochman', 'chippincookie', 'swang330']
# - Cycle 43: ['liam_hochman', 'noahpurow', 'elijahaharris']
# - Cycle 44: ['liam_hochman', 'chrishussey_', 'swang330']
# - Cycle 45: ['liam_hochman', 'kourtelise', 'swang330']
# - Cycle 46: ['liam_hochman', '_jasonreiser_', 'alex.kalis']
# - Cycle 47: ['liam_hochman', 'alexpicoult', 'kirindanek']
# - Cycle 48: ['lise.y', 'alexandrapurdy_', 'kabir_aho']
# - Cycle 49: ['brndayle', 'seoeunki.m', 'kirindanek']
# - Cycle 50: ['lavleen131', 'noahpurow', 'elybrayboy']
# - Cycle 51: ['ilanagoldklang', 'alex.kalis', 'will.deley']
# - Cycle 52: ['kirindanek', 'dnedtr', 'zach.annuik']
# - Cycle 53: ['kirindanek', 'michael.shaari', 'noahpurow']
# - Cycle 54: ['kirindanek', 'mette.mck', 'alexandrapurdy_']
# - Cycle 55: ['kirindanek', 'noahpurow', 'chichichi_le']
# - Cycle 56: ['kirindanek', '_elle.gray_', 'elybrayboy']
# - Cycle 57: ['kirindanek', 'guslafave', 'noahpurow']
# - Cycle 58: ['kirindanek', 'guslafave', 'elybrayboy']
# - Cycle 59: ['meforpresidentlol', 'elybrayboy', 'noahpurow']
# - Cycle 60: ['jonas_l03', 'noahpurow', 'elybrayboy']
# - Cycle 61: ['park_connor', 'seoeunki.m', 'swang330']
# - Cycle 62: ['kieran_lucus', 'elybrayboy', 'noahpurow']
# - Cycle 63: ['swang330', 'sanah_218', 'seoeunki.m']
# - Cycle 64: ['swang330', 'angelajchen_', 'seoeunki.m']
# - Cycle 65: ['swang330', '_alanmoon', 'seoeunki.m']
# - Cycle 66: ['ellaahongg', 'zach.annuik', 'alex.kalis']
# - Cycle 67: ['elijahaharris', 'elybrayboy', 'noahpurow']
# - Cycle 68: ['ju_at_uni', 'elybrayboy', 'noahpurow']
# - Cycle 69: ['sofiaegge', 'elybrayboy', 'noahpurow']
# - Cycle 70: ['elybrayboy', 'zach.annuik', 'avivaraefreedberg']
# - Cycle 71: ['elybrayboy', 'zach.annuik', 'fiona.vail']
# - Cycle 72: ['elybrayboy', 'noahpurow', 'shruti.panse3']
# - Cycle 73: ['elybrayboy', 'noahpurow', 'fillip.gold']
# - Cycle 74: ['elybrayboy', 'noahpurow', 'morgansvenningsen']
# - Cycle 75: ['elybrayboy', 'noahpurow', 'herbie.martinn']
# - Cycle 76: ['elybrayboy', 'noahpurow', 'mateen_mark']
# - Cycle 77: ['elybrayboy', 'noahpurow', 'julia_patterson123']
# - Cycle 78: ['elybrayboy', 'noahpurow', 'jessica.lin._']
# - Cycle 79: ['elybrayboy', 'noahpurow', 'escoop5']
# - Cycle 80: ['elybrayboy', 'noahpurow', 'emilymrakovcic']
# - Cycle 81: ['elybrayboy', 'noahpurow', 'jcesph']
# - Cycle 82: ['elybrayboy', 'noahpurow', 'nat.cavallo']
# - Cycle 83: ['elybrayboy', 'noahpurow', 'shrita_reddy']
# - Cycle 84: ['elybrayboy', 'noahpurow', 'preetishjuneja']
# - Cycle 85: ['elybrayboy', 'noahpurow', 'sophjaeger']
# - Cycle 86: ['elybrayboy', 'noahpurow', 'dxma03']
# - Cycle 87: ['elybrayboy', 'noahpurow', 'jackson.deborde']
# - Cycle 88: ['elybrayboy', 'noahpurow', 'mollyleubner']
# - Cycle 89: ['elybrayboy', 'noahpurow', 'ebanibani']
# - Cycle 90: ['elybrayboy', 'noahpurow', 'kelvinjiang__']
# - Cycle 91: ['elybrayboy', 'noahpurow', '_sophialim']
# - Cycle 92: ['elybrayboy', 'noahpurow', 'marlo.hulnick']
# - Cycle 93: ['elybrayboy', 'noahpurow', '_francesca_elia']
# - Cycle 94: ['elybrayboy', 'noahpurow', 'tats_daniel']
# - Cycle 95: ['elybrayboy', 'noahpurow', 'junnie.kimm']
# - Cycle 96: ['elybrayboy', 'holdenaxel', 'zach.annuik']
# - Cycle 97: ['elybrayboy', 'michael.shaari', 'noahpurow']
# - Cycle 98: ['elybrayboy', 'shana_xia', 'noahpurow']
# - Cycle 99: ['elybrayboy', 'carys.edwards_', 'noahpurow']
# - Cycle 100: ['elybrayboy', 'johnnysoscia', 'noahpurow']
# - Cycle 101: ['elybrayboy', 'chief_javin', 'noahpurow']
# - Cycle 102: ['elybrayboy', 'alexis.h9', 'noahpurow']
# - Cycle 103: ['elybrayboy', 'adelaideeeeeee', 'noahpurow']
# - Cycle 104: ['elybrayboy', '_mirawhite', 'noahpurow']
# - Cycle 105: ['elybrayboy', 'dsalvin9', 'noahpurow']
# - Cycle 106: ['elybrayboy', 'safwan.is', 'noahpurow']
# - Cycle 107: ['elybrayboy', 'not.senyi', 'alex.kalis']
# - Cycle 108: ['elybrayboy', 'amie.barrow', 'noahpurow']
# - Cycle 109: ['elybrayboy', 'diorlord', 'noahpurow']
# - Cycle 110: ['dnedtr', 'zach.annuik', 'kabir_aho']
# - Cycle 111: ['mayagalpern', 'will.deley', 'alex.kalis']
# - Cycle 112: ['soph_rogers', 'alex.kalis', 'will.deley']
# - Cycle 113: ['will.deley', 'alex.kalis', 'pranshudewagan_']
# - Cycle 114: ['will.deley', 'alex.kalis', 'alxshpakov']
# - Cycle 115: ['will.deley', 'alex.kalis', 'owenphelps3']
# - Cycle 116: ['will.deley', 'gaby.soen', 'alex.kalis']
# - Cycle 117: ['will.deley', 'jack.wiitanen', 'alex.kalis']
# - Cycle 118: ['alexandrapurdy_', 'seoeunki.m', '_anders_hansen']
# - Cycle 119: ['alexandrapurdy_', 'soph.zwu', 'zach.annuik']
# - Cycle 120: ['kaitlynhong_', 'alex.kalis', 'seoeunki.m']

# %% [markdown]
# ## All cycles of length 3

# %%
all_cycles_len3_distinct = []
if lscc_graph:
    print("\n--- All Simple 3-Cycle Search (Full LSCC) ---")
    target_graph = lscc_graph
    start_time = time.time()

    found_unique_cycles_set = set()

    for u in target_graph:
        for v in target_graph[u]:
            for w in target_graph[v]:
                # simple 3-cycle (distinct nodes)
                if w != u and v != w and target_graph.has_edge(w, u):
                    cycle = [u, v, w]
                    # identifier
                    sorted_cycle_tuple = tuple(sorted(cycle))
                    if sorted_cycle_tuple not in found_unique_cycles_set:
                        found_unique_cycles_set.add(sorted_cycle_tuple)
                        all_cycles_len3_distinct.append(cycle)

    end_time = time.time()
    found_count = len(all_cycles_len3_distinct)
    print(f"\nSearch Complete. Found {found_count} unique simple cycles of length 3.")
    print(f"Time taken: {end_time - start_time:.2f} seconds.")

    # Print a limited number
    PRINT_LIMIT = 20
    if all_cycles_len3_distinct:
        print(f"\nPrinting unique length 3 simple cycles found:")
        for i, cycle in enumerate(all_cycles_len3_distinct):
            print(f"-Cycle {i+1}: {cycle}")
# Out:
# --- All Simple 3-Cycle Search (Full LSCC) ---
#
# Search Complete. Found 380 unique simple cycles of length 3.
# Time taken: 4.01 seconds.
#
# Printing unique length 3 simple cycles found:
# -Cycle 1: ['samantha_klein__', 'noahpurow', 'elybrayboy']
# -Cycle 2: ['anderss.k', 'zach.annuik', 'kirindanek']
# -Cycle 3: ['anderss.k', 'zach.annuik', 'kabir_aho']
# -Cycle 4: ['feyza_achilova', 'elybrayboy', 'noahpurow']
# -Cycle 5: ['madigoeke', 'elybrayboy', 'noahpurow']
# -Cycle 6: ['zabei.frank', 'liam_hochman', 'swang330']
# -Cycle 7: ['harshxk_', 'will.deley', 'alex.kalis']
# -Cycle 8: ['cayeetanaaa', 'noahpurow', 'elybrayboy']
# -Cycle 9: ['savvyng', 'swang330', 'seoeunki.m']
# -Cycle 10: ['brownumemes', 'elybrayboy', 'noahpurow']
# -Cycle 11: ['jake_levy61', 'will.deley', 'alex.kalis']
# -Cycle 12: ['_annikasingh', 'noahpurow', 'elybrayboy']
# -Cycle 13: ['yota.katsikouli', 'swang330', 'kirindanek']
# -Cycle 14: ['eledeff', 'liam_hochman', 'swang330']
# -Cycle 15: ['_jackchin', 'liam_hochman', 'swang330']
# -Cycle 16: ['libbydakers', 'elybrayboy', 'noahpurow']
# -Cycle 17: ['myopiamilos', 'swang330', 'liam_hochman']
# -Cycle 18: ['katy_wales17', 'alex.kalis', 'will.deley']
# -Cycle 19: ['kaylenmelissaa', 'noahpurow', 'elybrayboy']
# -Cycle 20: ['baybater', 'swang330', 'liam_hochman']
# -Cycle 21: ['baybater', 'swang330', 'alex.kalis']
# -Cycle 22: ['lylahaikoye', 'seoeunki.m', 'will.deley']
# -Cycle 23: ['arsh_chow', 'seoeunki.m', 'kabir_aho']
# -Cycle 24: ['_harrison.brown_', 'liam_hochman', 'swang330']
# -Cycle 25: ['hofmanntheo', 'seoeunki.m', 'alexandrapurdy_']
# -Cycle 26: ['michaelpyo_', 'zach.annuik', 'kabir_aho']
# -Cycle 27: ['katrinatruong', 'elybrayboy', 'noahpurow']
# -Cycle 28: ['edgr_oh', 'zach.annuik', 'alexandrapurdy_']
# -Cycle 29: ['yenee.b3', 'noahpurow', 'elybrayboy']
# -Cycle 30: ['a.fitenko', 'seoeunki.m', 'liam_hochman']
# -Cycle 31: ['annie.ye', 'noahpurow', 'elybrayboy']
# -Cycle 32: ['avaslewis', 'noahpurow', 'elybrayboy']
# -Cycle 33: ['catherinejia_', 'elybrayboy', 'noahpurow']
# -Cycle 34: ['_kate.choi', 'noahpurow', 'elybrayboy']
# -Cycle 35: ['juliagallent_', 'noahpurow', 'elybrayboy']
# -Cycle 36: ['cara.ninaa', 'noahpurow', 'elybrayboy']
# -Cycle 37: ['lucyc1ark', 'zach.annuik', 'elybrayboy']
# -Cycle 38: ['ak.shay_mehta', 'noahpurow', 'elybrayboy']
# -Cycle 39: ['marazwicker_', 'will.deley', 'alex.kalis']
# -Cycle 40: ['ajhaveri1', 'noahpurow', 'elybrayboy']
# -Cycle 41: ['liam_hochman', 'zach.annuik', 'swang330']
# -Cycle 42: ['liam_hochman', 'zach.annuik', 'alex.kalis']
# -Cycle 43: ['liam_hochman', 'zach.annuik', 'kirindanek']
# -Cycle 44: ['liam_hochman', 'zach.annuik', 'noahpurow']
# -Cycle 45: ['liam_hochman', 'zach.annuik', 'seoeunki.m']
# -Cycle 46: ['liam_hochman', 'zach.annuik', 'will.deley']
# -Cycle 47: ['liam_hochman', 'zach.annuik', 'alexandrapurdy_']
# -Cycle 48: ['liam_hochman', 'swang330', 'o_ovaltine267']
# -Cycle 49: ['liam_hochman', 'swang330', 'peterschwammy']
# -Cycle 50: ['liam_hochman', 'swang330', 'mia._.adler']
# -Cycle 51: ['liam_hochman', 'swang330', 'grace.zhengg']
# -Cycle 52: ['liam_hochman', 'swang330', 'leila.sahyoun']
# -Cycle 53: ['liam_hochman', 'swang330', 'rezspuffs']
# -Cycle 54: ['liam_hochman', 'swang330', 'ryanstracks']
# -Cycle 55: ['liam_hochman', 'swang330', 'alyssa.pedicino']
# -Cycle 56: ['liam_hochman', 'swang330', '3liana_mn']
# -Cycle 57: ['liam_hochman', 'swang330', 'kenneth.feliz']
# -Cycle 58: ['liam_hochman', 'swang330', 'robin8er']
# -Cycle 59: ['liam_hochman', 'swang330', 'dan_klein1']
# -Cycle 60: ['liam_hochman', 'swang330', 'joshu.ms']
# -Cycle 61: ['liam_hochman', 'swang330', 'brandon_right.now']
# -Cycle 62: ['liam_hochman', 'swang330', 'lexi.duffy']
# -Cycle 63: ['liam_hochman', 'swang330', 'adrianwclement']
# -Cycle 64: ['liam_hochman', 'swang330', 'jake_cole08']
# -Cycle 65: ['liam_hochman', 'swang330', 'jacobzarate13']
# -Cycle 66: ['liam_hochman', 'swang330', 'kaiiiii__5']
# -Cycle 67: ['liam_hochman', 'swang330', 'anastasia.karavasili']
# -Cycle 68: ['liam_hochman', 'swang330', 'sabrinaw.64']
# -Cycle 69: ['liam_hochman', 'swang330', 'brianngiraud']
# -Cycle 70: ['liam_hochman', 'swang330', 'emma.newman30']
# -Cycle 71: ['liam_hochman', 'swang330', 'kayln_']
# -Cycle 72: ['liam_hochman', 'swang330', 'alexandrapurdy_']
# -Cycle 73: ['liam_hochman', 'swang330', 'j.dstag']
# -Cycle 74: ['liam_hochman', 'swang330', 'tslnew']
# -Cycle 75: ['liam_hochman', 'swang330', 'shreya.lakshmi.balaji']
# -Cycle 76: ['liam_hochman', 'swang330', 'chloesross']
# -Cycle 77: ['liam_hochman', 'swang330', 'seoeunki.m']
# -Cycle 78: ['liam_hochman', 'swang330', 'bennetdude']
# -Cycle 79: ['liam_hochman', 'swang330', 'danianabtawi']
# -Cycle 80: ['liam_hochman', 'swang330', 'nhingocngech']
# -Cycle 81: ['liam_hochman', 'swang330', 'ericyhli']
# -Cycle 82: ['liam_hochman', 'swang330', 'jonahacraine']
# -Cycle 83: ['liam_hochman', 'swang330', 'will.deley']
# -Cycle 84: ['liam_hochman', 'swang330', 'alex.kalis']
# -Cycle 85: ['liam_hochman', 'swang330', 'noahpurow']
# -Cycle 86: ['liam_hochman', 'swang330', 'kirindanek']
# -Cycle 87: ['liam_hochman', 'swang330', 'geraldthepomelo']
# -Cycle 88: ['liam_hochman', 'swang330', '_sararhe_']
# -Cycle 89: ['liam_hochman', 'alex.kalis', 'will.deley']
# -Cycle 90: ['liam_hochman', 'alex.kalis', 'kirindanek']
# -Cycle 91: ['liam_hochman', 'alex.kalis', 'seoeunki.m']
# -Cycle 92: ['liam_hochman', 'alex.kalis', 'alexandrapurdy_']
# -Cycle 93: ['liam_hochman', 'alex.kalis', 'noahpurow']
# -Cycle 94: ['liam_hochman', 'will.deley', 'kirindanek']
# -Cycle 95: ['liam_hochman', 'will.deley', 'noahpurow']
# -Cycle 96: ['liam_hochman', 'will.deley', 'seoeunki.m']
# -Cycle 97: ['liam_hochman', 'will.deley', 'alexandrapurdy_']
# -Cycle 98: ['liam_hochman', 'emilycharestt', 'swang330']
# -Cycle 99: ['liam_hochman', 'kellxj', 'swang330']
# -Cycle 100: ['liam_hochman', 'kirindanek', 'seoeunki.m']
# -Cycle 101: ['liam_hochman', 'kirindanek', 'noahpurow']
# -Cycle 102: ['liam_hochman', 'kirindanek', 'lillieofthesky']
# -Cycle 103: ['liam_hochman', 'kirindanek', 'alexandrapurdy_']
# -Cycle 104: ['liam_hochman', 'taramukund', 'swang330']
# -Cycle 105: ['liam_hochman', 'jjessica.zhang', 'swang330']
# -Cycle 106: ['liam_hochman', 'scrippsadvocates', 'swang330']
# -Cycle 107: ['liam_hochman', 'seoeunki.m', 'noahpurow']
# -Cycle 108: ['liam_hochman', 'seoeunki.m', 'alexandrapurdy_']
# -Cycle 109: ['liam_hochman', 'seoeunki.m', '3liana_mn']
# -Cycle 110: ['liam_hochman', 'seoeunki.m', '_anders_hansen']
# -Cycle 111: ['liam_hochman', 'alexandrapurdy_', 'noahpurow']
# -Cycle 112: ['liam_hochman', 'alexandrapurdy_', 'solanaoshea']
# -Cycle 113: ['liam_hochman', 'alexandrapurdy_', 'soph.zwu']
# -Cycle 114: ['liam_hochman', 'alexandrapurdy_', 'nadia.schwartz']
# -Cycle 115: ['liam_hochman', 'alexandrapurdy_', '_anders_hansen']
# -Cycle 116: ['liam_hochman', 'chippincookie', 'swang330']
# -Cycle 117: ['liam_hochman', 'noahpurow', 'emilypollins']
# -Cycle 118: ['liam_hochman', 'noahpurow', 'elijahaharris']
# -Cycle 119: ['liam_hochman', 'chrishussey_', 'swang330']
# -Cycle 120: ['liam_hochman', 'kourtelise', 'swang330']
# -Cycle 121: ['liam_hochman', '_jasonreiser_', 'alex.kalis']
# -Cycle 122: ['liam_hochman', 'alexpicoult', 'kirindanek']
# -Cycle 123: ['lise.y', 'alexandrapurdy_', 'kabir_aho']
# -Cycle 124: ['brndayle', 'seoeunki.m', 'kirindanek']
# -Cycle 125: ['lavleen131', 'noahpurow', 'elybrayboy']
# -Cycle 126: ['ilanagoldklang', 'alex.kalis', 'will.deley']
# -Cycle 127: ['avapellagrini', 'noahpurow', 'elybrayboy']
# -Cycle 128: ['kirindanek', 'zach.annuik', 'swang330']
# -Cycle 129: ['kirindanek', 'zach.annuik', 'alex.kalis']
# -Cycle 130: ['kirindanek', 'zach.annuik', 'noahpurow']
# -Cycle 131: ['kirindanek', 'zach.annuik', 'seoeunki.m']
# -Cycle 132: ['kirindanek', 'zach.annuik', 'elybrayboy']
# -Cycle 133: ['kirindanek', 'zach.annuik', 'will.deley']
# -Cycle 134: ['kirindanek', 'zach.annuik', 'alexandrapurdy_']
# -Cycle 135: ['kirindanek', 'swang330', 'alexandrapurdy_']
# -Cycle 136: ['kirindanek', 'swang330', 'seoeunki.m']
# -Cycle 137: ['kirindanek', 'swang330', 'elybrayboy']
# -Cycle 138: ['kirindanek', 'swang330', 'will.deley']
# -Cycle 139: ['kirindanek', 'swang330', 'alex.kalis']
# -Cycle 140: ['kirindanek', 'swang330', 'noahpurow']
# -Cycle 141: ['kirindanek', 'alex.kalis', 'will.deley']
# -Cycle 142: ['kirindanek', 'alex.kalis', 'elybrayboy']
# -Cycle 143: ['kirindanek', 'alex.kalis', 'seoeunki.m']
# -Cycle 144: ['kirindanek', 'alex.kalis', 'alexandrapurdy_']
# -Cycle 145: ['kirindanek', 'alex.kalis', 'noahpurow']
# -Cycle 146: ['kirindanek', 'will.deley', 'noahpurow']
# -Cycle 147: ['kirindanek', 'will.deley', 'seoeunki.m']
# -Cycle 148: ['kirindanek', 'will.deley', 'elybrayboy']
# -Cycle 149: ['kirindanek', 'will.deley', 'alexandrapurdy_']
# -Cycle 150: ['kirindanek', 'elybrayboy', 'alexandrapurdy_']
# -Cycle 151: ['kirindanek', 'elybrayboy', 'seoeunki.m']
# -Cycle 152: ['kirindanek', 'elybrayboy', 'noahpurow']
# -Cycle 153: ['kirindanek', 'seoeunki.m', 'noahpurow']
# -Cycle 154: ['kirindanek', 'seoeunki.m', 'alexandrapurdy_']
# -Cycle 155: ['kirindanek', 'dnedtr', 'zach.annuik']
# -Cycle 156: ['kirindanek', 'michael.shaari', 'noahpurow']
# -Cycle 157: ['kirindanek', 'mette.mck', 'alexandrapurdy_']
# -Cycle 158: ['kirindanek', 'noahpurow', 'chichichi_le']
# -Cycle 159: ['kirindanek', 'noahpurow', 'alexandrapurdy_']
# -Cycle 160: ['kirindanek', '_elle.gray_', 'elybrayboy']
# -Cycle 161: ['kirindanek', 'guslafave', 'noahpurow']
# -Cycle 162: ['kirindanek', 'guslafave', 'elybrayboy']
# -Cycle 163: ['ella.sheidley', 'seoeunki.m', 'alexandrapurdy_']
# -Cycle 164: ['meforpresidentlol', 'elybrayboy', 'noahpurow']
# -Cycle 165: ['minsungellie', 'noahpurow', 'elybrayboy']
# -Cycle 166: ['jonas_l03', 'noahpurow', 'elybrayboy']
# -Cycle 167: ['a.kokoricha', 'noahpurow', 'elybrayboy']
# -Cycle 168: ['park_connor', 'seoeunki.m', 'swang330']
# -Cycle 169: ['jasonstoptier', 'noahpurow', 'elybrayboy']
# -Cycle 170: ['guslafave', 'noahpurow', 'elybrayboy']
# -Cycle 171: ['will.b.lambert', 'zach.annuik', 'seoeunki.m']
# -Cycle 172: ['molly_ribeiro8', 'noahpurow', 'elybrayboy']
# -Cycle 173: ['kieran_lucus', 'elybrayboy', 'noahpurow']
# -Cycle 174: ['swang330', 'sanah_218', 'seoeunki.m']
# -Cycle 175: ['swang330', 'itzkim_y', 'elybrayboy']
# -Cycle 176: ['swang330', '3liana_mn', 'seoeunki.m']
# -Cycle 177: ['swang330', 'anjali.nuggehalli', 'seoeunki.m']
# -Cycle 178: ['swang330', 'oliviamatlaga', 'alexandrapurdy_']
# -Cycle 179: ['swang330', 'alexandrapurdy_', 'zach.annuik']
# -Cycle 180: ['swang330', 'alexandrapurdy_', 'alex.kalis']
# -Cycle 181: ['swang330', 'alexandrapurdy_', 'kabir_aho']
# -Cycle 182: ['swang330', 'alexandrapurdy_', 'noahpurow']
# -Cycle 183: ['swang330', 'alexandrapurdy_', 'seoeunki.m']
# -Cycle 184: ['swang330', 'alexandrapurdy_', 'elybrayboy']
# -Cycle 185: ['swang330', 'alexandrapurdy_', 'will.deley']
# -Cycle 186: ['swang330', 'alexandrapurdy_', 'laney.mcd']
# -Cycle 187: ['swang330', 'seoeunki.m', 'alex.kalis']
# -Cycle 188: ['swang330', 'seoeunki.m', 'kabir_aho']
# -Cycle 189: ['swang330', 'seoeunki.m', 'noahpurow']
# -Cycle 190: ['swang330', 'seoeunki.m', 'elybrayboy']
# -Cycle 191: ['swang330', 'seoeunki.m', 'will.deley']
# -Cycle 192: ['swang330', 'seoeunki.m', 'zach.annuik']
# -Cycle 193: ['swang330', 'elybrayboy', 'zach.annuik']
# -Cycle 194: ['swang330', 'elybrayboy', 'alex.kalis']
# -Cycle 195: ['swang330', 'elybrayboy', 'will.deley']
# -Cycle 196: ['swang330', 'elybrayboy', 'noahpurow']
# -Cycle 197: ['swang330', 'kabir_aho', 'zach.annuik']
# -Cycle 198: ['swang330', 'kabir_aho', 'will.deley']
# -Cycle 199: ['swang330', 'kabir_aho', 'noahpurow']
# -Cycle 200: ['swang330', 'will.deley', 'zach.annuik']
# -Cycle 201: ['swang330', 'will.deley', 'alex.kalis']
# -Cycle 202: ['swang330', 'will.deley', 'noahpurow']
# -Cycle 203: ['swang330', 'angelajchen_', 'seoeunki.m']
# -Cycle 204: ['swang330', 'alex.kalis', 'zach.annuik']
# -Cycle 205: ['swang330', 'alex.kalis', 'noahpurow']
# -Cycle 206: ['swang330', 'noahpurow', 'zach.annuik']
# -Cycle 207: ['swang330', '_alanmoon', 'seoeunki.m']
# -Cycle 208: ['kathalyn.do', 'noahpurow', 'elybrayboy']
# -Cycle 209: ['ellaahongg', 'zach.annuik', 'alex.kalis']
# -Cycle 210: ['j_jchill', 'noahpurow', 'elybrayboy']
# -Cycle 211: ['ben_mun_', 'alex.kalis', 'seoeunki.m']
# -Cycle 212: ['elijahaharris', 'elybrayboy', 'noahpurow']
# -Cycle 213: ['ju_at_uni', 'elybrayboy', 'noahpurow']
# -Cycle 214: ['sofiaegge', 'elybrayboy', 'noahpurow']
# -Cycle 215: ['ellapark_', 'noahpurow', 'elybrayboy']
# -Cycle 216: ['mar.melzer', 'noahpurow', 'elybrayboy']
# -Cycle 217: ['shaoyxx', 'seoeunki.m', 'elybrayboy']
# -Cycle 218: ['trinsimone', 'noahpurow', 'elybrayboy']
# -Cycle 219: ['riann_s29', 'alex.kalis', 'will.deley']
# -Cycle 220: ['elybrayboy', 'zach.annuik', 'alex.kalis']
# -Cycle 221: ['elybrayboy', 'zach.annuik', 'avivaraefreedberg']
# -Cycle 222: ['elybrayboy', 'zach.annuik', 'fiona.vail']
# -Cycle 223: ['elybrayboy', 'zach.annuik', 'noahpurow']
# -Cycle 224: ['elybrayboy', 'zach.annuik', 'seoeunki.m']
# -Cycle 225: ['elybrayboy', 'zach.annuik', 'will.deley']
# -Cycle 226: ['elybrayboy', 'zach.annuik', 'alexandrapurdy_']
# -Cycle 227: ['elybrayboy', 'alex.kalis', 'will.deley']
# -Cycle 228: ['elybrayboy', 'alex.kalis', 'seoeunki.m']
# -Cycle 229: ['elybrayboy', 'alex.kalis', 'alexandrapurdy_']
# -Cycle 230: ['elybrayboy', 'alex.kalis', 'noahpurow']
# -Cycle 231: ['elybrayboy', 'alexandrapurdy_', 'noahpurow']
# -Cycle 232: ['elybrayboy', 'alexandrapurdy_', 'seoeunki.m']
# -Cycle 233: ['elybrayboy', 'alexandrapurdy_', 'will.deley']
# -Cycle 234: ['elybrayboy', 'seoeunki.m', 'noahpurow']
# -Cycle 235: ['elybrayboy', 'seoeunki.m', 'will.deley']
# -Cycle 236: ['elybrayboy', 'will.deley', 'noahpurow']
# -Cycle 237: ['elybrayboy', 'noahpurow', 'charcastillo_']
# -Cycle 238: ['elybrayboy', 'noahpurow', 'gm_venegas']
# -Cycle 239: ['elybrayboy', 'noahpurow', 'yunus_yjh']
# -Cycle 240: ['elybrayboy', 'noahpurow', 'shruti.panse3']
# -Cycle 241: ['elybrayboy', 'noahpurow', 'samanthachamberss']
# -Cycle 242: ['elybrayboy', 'noahpurow', 'taliaslevine']
# -Cycle 243: ['elybrayboy', 'noahpurow', 'joshgabbai']
# -Cycle 244: ['elybrayboy', 'noahpurow', 'zaktheman04']
# -Cycle 245: ['elybrayboy', 'noahpurow', 'sanjanahmath']
# -Cycle 246: ['elybrayboy', 'noahpurow', 'hotgrrlriot']
# -Cycle 247: ['elybrayboy', 'noahpurow', 'kaydenmillerr']
# -Cycle 248: ['elybrayboy', 'noahpurow', 'brookewangenheim']
# -Cycle 249: ['elybrayboy', 'noahpurow', 'muzalakawatu']
# -Cycle 250: ['elybrayboy', 'noahpurow', 'rowlandlawver']
# -Cycle 251: ['elybrayboy', 'noahpurow', 'annaasamel']
# -Cycle 252: ['elybrayboy', 'noahpurow', 'fillip.gold']
# -Cycle 253: ['elybrayboy', 'noahpurow', 'morgansvenningsen']
# -Cycle 254: ['elybrayboy', 'noahpurow', 'ellehorst_']
# -Cycle 255: ['elybrayboy', 'noahpurow', 'v1saal']
# -Cycle 256: ['elybrayboy', 'noahpurow', 'herbie.martinn']
# -Cycle 257: ['elybrayboy', 'noahpurow', 'sophia.cheng_']
# -Cycle 258: ['elybrayboy', 'noahpurow', 'queenreinaiv']
# -Cycle 259: ['elybrayboy', 'noahpurow', 'mateen_mark']
# -Cycle 260: ['elybrayboy', 'noahpurow', 'julia_patterson123']
# -Cycle 261: ['elybrayboy', 'noahpurow', 'kailee.tanaka']
# -Cycle 262: ['elybrayboy', 'noahpurow', 'sarahridleyy']
# -Cycle 263: ['elybrayboy', 'noahpurow', 'jessica.lin._']
# -Cycle 264: ['elybrayboy', 'noahpurow', 'escoop5']
# -Cycle 265: ['elybrayboy', 'noahpurow', 'ela.snyder']
# -Cycle 266: ['elybrayboy', 'noahpurow', 'emilymrakovcic']
# -Cycle 267: ['elybrayboy', 'noahpurow', 'jcesph']
# -Cycle 268: ['elybrayboy', 'noahpurow', 'nat.cavallo']
# -Cycle 269: ['elybrayboy', 'noahpurow', 'shrita_reddy']
# -Cycle 270: ['elybrayboy', 'noahpurow', 'preetishjuneja']
# -Cycle 271: ['elybrayboy', 'noahpurow', 'sophjaeger']
# -Cycle 272: ['elybrayboy', 'noahpurow', 'dxma03']
# -Cycle 273: ['elybrayboy', 'noahpurow', 'jeremyyoung___']
# -Cycle 274: ['elybrayboy', 'noahpurow', 'umizen']
# -Cycle 275: ['elybrayboy', 'noahpurow', 'juliasiko']
# -Cycle 276: ['elybrayboy', 'noahpurow', 'jackson.deborde']
# -Cycle 277: ['elybrayboy', 'noahpurow', 'slim.shadi44']
# -Cycle 278: ['elybrayboy', 'noahpurow', 'mollyleubner']
# -Cycle 279: ['elybrayboy', 'noahpurow', 'ebanibani']
# -Cycle 280: ['elybrayboy', 'noahpurow', 'kelvinjiang__']
# -Cycle 281: ['elybrayboy', 'noahpurow', '_sophialim']
# -Cycle 282: ['elybrayboy', 'noahpurow', '_livvfox']
# -Cycle 283: ['elybrayboy', 'noahpurow', 'sophia_esch']
# -Cycle 284: ['elybrayboy', 'noahpurow', 'marlo.hulnick']
# -Cycle 285: ['elybrayboy', 'noahpurow', 'sam.d.01']
# -Cycle 286: ['elybrayboy', 'noahpurow', '_francesca_elia']
# -Cycle 287: ['elybrayboy', 'noahpurow', 'tats_daniel']
# -Cycle 288: ['elybrayboy', 'noahpurow', 'junnie.kimm']
# -Cycle 289: ['elybrayboy', 'noahpurow', 'zoemschwartz']
# -Cycle 290: ['elybrayboy', 'noahpurow', 'knight.cc']
# -Cycle 291: ['elybrayboy', 'noahpurow', 'anikamahns']
# -Cycle 292: ['elybrayboy', 'holdenaxel', 'zach.annuik']
# -Cycle 293: ['elybrayboy', 'michael.shaari', 'noahpurow']
# -Cycle 294: ['elybrayboy', 'shana_xia', 'noahpurow']
# -Cycle 295: ['elybrayboy', 'carys.edwards_', 'noahpurow']
# -Cycle 296: ['elybrayboy', 'johnnysoscia', 'noahpurow']
# -Cycle 297: ['elybrayboy', 'chief_javin', 'noahpurow']
# -Cycle 298: ['elybrayboy', 'alexis.h9', 'noahpurow']
# -Cycle 299: ['elybrayboy', 'adelaideeeeeee', 'noahpurow']
# -Cycle 300: ['elybrayboy', '_mirawhite', 'noahpurow']
# -Cycle 301: ['elybrayboy', 'dsalvin9', 'noahpurow']
# -Cycle 302: ['elybrayboy', 'safwan.is', 'noahpurow']
# -Cycle 303: ['elybrayboy', 'not.senyi', 'alex.kalis']
# -Cycle 304: ['elybrayboy', 'amie.barrow', 'noahpurow']
# -Cycle 305: ['elybrayboy', 'diorlord', 'noahpurow']
# -Cycle 306: ['dnedtr', 'zach.annuik', 'kabir_aho']
# -Cycle 307: ['mayagalpern', 'will.deley', 'alex.kalis']
# -Cycle 308: ['soph_rogers', 'alex.kalis', 'will.deley']
# -Cycle 309: ['matthew.grossman', 'noahpurow', 'alexandrapurdy_']
# -Cycle 310: ['noahpurow', 'zach.annuik', 'alex.kalis']
# -Cycle 311: ['noahpurow', 'zach.annuik', 'kabir_aho']
# -Cycle 312: ['noahpurow', 'zach.annuik', 'seoeunki.m']
# -Cycle 313: ['noahpurow', 'zach.annuik', 'will.deley']
# -Cycle 314: ['noahpurow', 'zach.annuik', 'alexandrapurdy_']
# -Cycle 315: ['noahpurow', 'alex.kalis', 'will.deley']
# -Cycle 316: ['noahpurow', 'alex.kalis', 'seoeunki.m']
# -Cycle 317: ['noahpurow', 'alex.kalis', 'alexandrapurdy_']
# -Cycle 318: ['noahpurow', 'seoeunki.m', 'kabir_aho']
# -Cycle 319: ['noahpurow', 'seoeunki.m', 'will.deley']
# -Cycle 320: ['noahpurow', 'seoeunki.m', 'alexandrapurdy_']
# -Cycle 321: ['noahpurow', 'seoeunki.m', 'mindy.kimm']
# -Cycle 322: ['noahpurow', 'will.deley', 'kabir_aho']
# -Cycle 323: ['noahpurow', 'will.deley', 'alexandrapurdy_']
# -Cycle 324: ['noahpurow', 'kabir_aho', 'alexandrapurdy_']
# -Cycle 325: ['noahpurow', 'alexandrapurdy_', 'tiffany.kuo']
# -Cycle 326: ['will.deley', 'zach.annuik', 'alex.kalis']
# -Cycle 327: ['will.deley', 'zach.annuik', 'kabir_aho']
# -Cycle 328: ['will.deley', 'zach.annuik', 'seoeunki.m']
# -Cycle 329: ['will.deley', 'zach.annuik', 'alexandrapurdy_']
# -Cycle 330: ['will.deley', 'alex.kalis', 'seoeunki.m']
# -Cycle 331: ['will.deley', 'alex.kalis', 'alexandrapurdy_']
# -Cycle 332: ['will.deley', 'alex.kalis', 'pranshudewagan_']
# -Cycle 333: ['will.deley', 'alex.kalis', 'presleypergande']
# -Cycle 334: ['will.deley', 'alex.kalis', 'alynnmcleod']
# -Cycle 335: ['will.deley', 'alex.kalis', 'brayankaspra']
# -Cycle 336: ['will.deley', 'alex.kalis', 'alxshpakov']
# -Cycle 337: ['will.deley', 'alex.kalis', 'owenphelps3']
# -Cycle 338: ['will.deley', 'alex.kalis', 'caitlyn.fung']
# -Cycle 339: ['will.deley', 'alex.kalis', 'jessiepolsonn']
# -Cycle 340: ['will.deley', 'alex.kalis', 'garvpundir01']
# -Cycle 341: ['will.deley', 'alex.kalis', 'hannahgotelaere']
# -Cycle 342: ['will.deley', 'kabir_aho', 'seoeunki.m']
# -Cycle 343: ['will.deley', 'kabir_aho', 'alexandrapurdy_']
# -Cycle 344: ['will.deley', 'seoeunki.m', 'alexandrapurdy_']
# -Cycle 345: ['will.deley', 'gaby.soen', 'alex.kalis']
# -Cycle 346: ['will.deley', 'jack.wiitanen', 'alex.kalis']
# -Cycle 347: ['alexandrapurdy_', 'zach.annuik', 'alex.kalis']
# -Cycle 348: ['alexandrapurdy_', 'zach.annuik', 'kabir_aho']
# -Cycle 349: ['alexandrapurdy_', 'zach.annuik', 'seoeunki.m']
# -Cycle 350: ['alexandrapurdy_', 'alex.kalis', 'seoeunki.m']
# -Cycle 351: ['alexandrapurdy_', 'kabir_aho', 'seoeunki.m']
# -Cycle 352: ['alexandrapurdy_', 'seoeunki.m', 'kate_a.s']
# -Cycle 353: ['alexandrapurdy_', 'seoeunki.m', '_anders_hansen']
# -Cycle 354: ['alexandrapurdy_', 'soph.zwu', 'zach.annuik']
# -Cycle 355: ['kaitlynhong_', 'alex.kalis', 'seoeunki.m']
# -Cycle 356: ['seoeunki.m', 'alex.kalis', 'zach.annuik']
# -Cycle 357: ['seoeunki.m', 'kabir_aho', 'zach.annuik']
# -Cycle 358: ['dis.copenhagen', 'dis.copenhagen', 'disdanmark']
# -Cycle 359: ['dis.copenhagen', 'dis.copenhagen', 'carletonocs']
# -Cycle 360: ['dis.copenhagen', 'dis.copenhagen', 'delphineecasp']
# -Cycle 361: ['dis.copenhagen', 'dis.copenhagen', 'kstateabroad']
# -Cycle 362: ['dis.copenhagen', 'dis.copenhagen', 'smith_college_ois']
# -Cycle 363: ['dis.copenhagen', 'dis.copenhagen', 'harnoorsachar']
# -Cycle 364: ['dis.copenhagen', 'dis.copenhagen', 'faeidhh']
# -Cycle 365: ['dis.copenhagen', 'dis.copenhagen', 'sally.bornhorst']
# -Cycle 366: ['dis.copenhagen', 'dis.copenhagen', 'aly.booth']
# -Cycle 367: ['dis.copenhagen', 'dis.copenhagen', 'mollyymaxwell']
# -Cycle 368: ['dis.copenhagen', 'dis.copenhagen', 'carnegiemellonabroad']
# -Cycle 369: ['dis.copenhagen', 'dis.copenhagen', 'gwabroad']
# -Cycle 370: ['dis.copenhagen', 'dis.copenhagen', 'mayastepic']
# -Cycle 371: ['dis.copenhagen', 'dis.copenhagen', 'wfustudyabroad']
# -Cycle 372: ['dis.copenhagen', 'dis.copenhagen', 'divya.bhargava_']
# -Cycle 373: ['dis.copenhagen', 'dis.copenhagen', 'studyabroadsju']
# -Cycle 374: ['dis.copenhagen', 'dis.copenhagen', 'annaaheninger']
# -Cycle 375: ['dis.copenhagen', 'dis.copenhagen', 'akasper1994']
# -Cycle 376: ['dis.copenhagen', 'dis.copenhagen', 'zane_hankin']
# -Cycle 377: ['dis.copenhagen', 'dis.copenhagen', 'max_jacobs3']
# -Cycle 378: ['dis.copenhagen', 'dis.copenhagen', 'jcheigh']
# -Cycle 379: ['dis.copenhagen', 'dis.copenhagen', 'next_door_cafe']
# -Cycle 380: ['dis.copenhagen', 'dis.copenhagen', 'melanie_gerko']

# %% [markdown]
# ## Proportion Asymetric

# %%
proportional_asymmetric = {}
#use counters for easier edefinitions
asymmetric_cycles_counter = Counter(node for cycle in asymmetric_cycles_len3 for node in cycle)

cycles_counter_len3_total = Counter(node for cycle in all_cycles_len3_distinct for node in cycle)

print(f"Asymmetric counts calculated for {len(asymmetric_cycles_counter)} nodes.")
print(f"Total distinct counts calculated for {len(cycles_counter_len3_total)} nodes.")

#calculate proportion
for username, total_count in cycles_counter_len3_total.items():
    asymmetric_count = asymmetric_cycles_counter.get(username, 0)
    proportional_asymmetric[username] = asymmetric_count / total_count

# sorted results
print("\nProportion of node's 3-cycle participation that is asymmetric (Top 20):")
sorted_proportions = sorted(proportional_asymmetric.items(), key=lambda item: item[1] if item[1] is not None else -1, reverse=True)

PRINT_LIMIT = 20
for i, (node, proportion) in enumerate(sorted_proportions[:PRINT_LIMIT]):
        if proportion is not None:
            asym_count_disp = asymmetric_cycles_counter.get(node, 0)
            total_count_disp = cycles_counter_len3_total.get(node, 'Error')
            print(f"- {node}: {proportion:.4f} ({asym_count_disp}/{total_count_disp})")
        else:
            print(f"-{node}: error")
# Out:
# Asymmetric counts calculated for 123 nodes.
# Total distinct counts calculated for 253 nodes.
#
# Proportion of node's 3-cycle participation that is asymmetric (Top 20):
# - anderss.k: 1.0000 (2/2)
# - feyza_achilova: 1.0000 (1/1)
# - madigoeke: 1.0000 (1/1)
# - harshxk_: 1.0000 (1/1)
# - cayeetanaaa: 1.0000 (1/1)
# - brownumemes: 1.0000 (1/1)
# - jake_levy61: 1.0000 (1/1)
# - _annikasingh: 1.0000 (1/1)
# - libbydakers: 1.0000 (1/1)
# - myopiamilos: 1.0000 (1/1)
# - katy_wales17: 1.0000 (1/1)
# - baybater: 1.0000 (2/2)
# - arsh_chow: 1.0000 (1/1)
# - _harrison.brown_: 1.0000 (1/1)
# - katrinatruong: 1.0000 (1/1)
# - edgr_oh: 1.0000 (1/1)
# - a.fitenko: 1.0000 (1/1)
# - catherinejia_: 1.0000 (1/1)
# - _kate.choi: 1.0000 (1/1)
# - lucyc1ark: 1.0000 (1/1)

# %%
class_member_usernames = set(username_dict.values())
found_members = {}

for node, proportion in sorted_proportions:
    if proportion is not None and node in class_member_usernames:
        found_members[node] = proportion

if found_members:
    # sort class members
    for node, prop in sorted(found_members.items(), key=lambda item: item[1], reverse=True):
        in_deg = lscc_graph.in_degree(node) if lscc_graph.has_node(node) else 'N/A'
        out_deg = lscc_graph.out_degree(node) if lscc_graph.has_node(node) else 'N/A'
        print(f"- {node}: {prop:.4f} (LSCC In={in_deg}, Out={out_deg})")
# Out:
# - elybrayboy: 0.4214 (LSCC In=708, Out=723)
# - noahpurow: 0.3709 (LSCC In=651, Out=684)
# - liam_hochman: 0.3146 (LSCC In=724, Out=739)
# - alex.kalis: 0.2787 (LSCC In=945, Out=951)
# - swang330: 0.2376 (LSCC In=662, Out=674)
# - kirindanek: 0.2340 (LSCC In=758, Out=768)
# - zach.annuik: 0.2075 (LSCC In=475, Out=471)
# - kabir_aho: 0.2000 (LSCC In=662, Out=670)
# - will.deley: 0.1967 (LSCC In=414, Out=413)
# - seoeunki.m: 0.1613 (LSCC In=764, Out=771)
# - alexandrapurdy_: 0.1429 (LSCC In=579, Out=588)
# - yota.katsikouli: 0.0000 (LSCC In=101, Out=101)
# - dis.copenhagen: 0.0000 (LSCC In=156, Out=24)
